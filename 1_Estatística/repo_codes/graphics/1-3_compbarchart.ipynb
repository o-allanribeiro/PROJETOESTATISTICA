# %% [markdown]
# # Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data to plot
n = 4
valores_A = [ 447.75, 385.54, 487.23, 632.77 ]
valores_B = [ 1873.29, 1476.11, 1649.62, 1920.1 ]

# %%
# create plot
fig, ax = plt.subplots ()
index = np.arange (n)

bar_width = 0.35
opacity = 0.8

bar_A = plt.bar (index, valores_A, bar_width, alpha=opacity, color= 'r', label= 'Argentina' )
bar_B = plt.bar (index + bar_width, valores_B, bar_width, alpha=opacity, color= 'y', label= 'Brazil' )

plt.xlabel ( 'Fonte Banco Mundial' )
plt.ylabel ( 'Bilhões USD' )
plt.title ( 'PIB por país' )
plt.xticks (index + bar_width, ( '2019', '2020', '2021', '2022' ))
plt.legend ()

plt.show ()
