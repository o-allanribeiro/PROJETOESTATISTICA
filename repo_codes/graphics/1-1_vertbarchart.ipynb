# %% [markdown]
# # Importar bibliotecas

# %%
import matplotlib.pyplot as plt

# %%
x = [ 'Python', 'C++', 'Java', 'Dart', 'C#', 'JavaScript' ]
y = [ 51, 62, 63, 54, 65, 65 ]

plt.bar (x, y, align= 'center', alpha= 0.5 )

plt.title ( 'Pesquisa de preferência - Evento 1 - Vertical' )
plt.xlabel ( 'Linguagens de programação' )
plt.ylabel ( 'Participantes' )
plt.savefig(r"C:\Users\allan\PROJETOESTATISTICA\Imagens\readme\vertbarchart.png")
plt.show ()
