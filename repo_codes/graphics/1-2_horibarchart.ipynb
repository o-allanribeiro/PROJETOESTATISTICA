# %% [markdown]
# # Importando bibliotecas

# %%
import matplotlib.pyplot as plt

# %%
x = [ 'Python', 'C++', 'Java', 'Dart', 'C#', 'JavaScript' ]
y = [ 51, 62, 63, 54, 65, 65 ]

plt.barh (x, y, align= 'center', alpha= 0.5 )

plt.title ( 'Pesquisa de preferência - Evento 1 - Horizontal' )
plt.ylabel ( 'Linguagens de programação' )
plt.xlabel ( 'Participantes' )
plt.savefig(r"C:\Users\allan\PROJETOESTATISTICA\Imagens\readme\horibarchart.png")
plt.show ()
